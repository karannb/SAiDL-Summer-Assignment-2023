# %%
from model_ import *
from expt_ import *
from trainer_ import *
import torch
import numpy as np
import matplotlib.pyplot as plt
import math

np.random.seed(1)
torch.manual_seed(1)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30, 15))
epochs = 10
Experiment1 = Expt(ax1, ax2, mode='delayed', dataset='expert', iterations=100, epochs=epochs, cell_type='RNN')

# %%
Experiment1.experiment()
legend = [f"epoch{math.ceil((num+1)/2)}_{3600 if num%2==0 else 1800}" for num in range(epochs*2)]
ax1.legend(legend, prop={"size":20})
ax2.legend(legend, prop={"size":20})
fig
# Out:
# objc[55076]: Class GLFWApplicationDelegate is implemented in both /Users/karan_bania/.mujoco/mujoco200/bin/libglfw.3.dylib (0x1045ec778) and /Users/karan_bania/anaconda3/envs/decision-transformer-gym/lib/python3.8/site-packages/glfw/libglfw.3.dylib (0x1050ef7e8). One of the two will be used. Which one is undefined.
# objc[55076]: Class GLFWWindowDelegate is implemented in both /Users/karan_bania/.mujoco/mujoco200/bin/libglfw.3.dylib (0x1045ec700) and /Users/karan_bania/anaconda3/envs/decision-transformer-gym/lib/python3.8/site-packages/glfw/libglfw.3.dylib (0x1050ef810). One of the two will be used. Which one is undefined.
# objc[55076]: Class GLFWContentView is implemented in both /Users/karan_bania/.mujoco/mujoco200/bin/libglfw.3.dylib (0x1045ec7a0) and /Users/karan_bania/anaconda3/envs/decision-transformer-gym/lib/python3.8/site-packages/glfw/libglfw.3.dylib (0x1050ef860). One of the two will be used. Which one is undefined.
# objc[55076]: Class GLFWWindow is implemented in both /Users/karan_bania/.mujoco/mujoco200/bin/libglfw.3.dylib (0x1045ec818) and /Users/karan_bania/anaconda3/envs/decision-transformer-gym/lib/python3.8/site-packages/glfw/libglfw.3.dylib (0x1050ef8d8). One of the two will be used. Which one is undefined.
# ==================================================
# Starting new experiment: expert
# 1027 trajectories, 999494 timesteps found
# Average return: 3511.36, std: 328.59
# Max return: 3759.08, min: 1645.28
# ==================================================
# ================================================================================
# Epoch 1
# time/training: 54.099220275878906
# evaluation/target_3600_return_mean: 23.55895098100533
# evaluation/target_3600_return_std: 1.3206944051566067
# evaluation/target_3600_length_mean: 19.7
# evaluation/target_3600_length_std: 0.7000000000000001
# evaluation/target_1800_return_mean: 12.022850323392884
# evaluation/target_1800_return_std: 0.48337196388470166
# evaluation/target_1800_length_mean: 13.65
# evaluation/target_1800_length_std: 0.4769696007084728
# time/total: 64.34490704536438
# time/evaluation: 10.24567699432373
# training/train_loss_mean: 2.3233670181035997
# training/train_loss_std: 0.659900126513608
# ================================================================================
# Epoch 2
# time/training: 56.30556321144104
# evaluation/target_3600_return_mean: 1281.2787048415835
# evaluation/target_3600_return_std: 956.0496890608167
# evaluation/target_3600_length_mean: 371.68
# evaluation/target_3600_length_std: 258.5077515278797
# evaluation/target_1800_return_mean: 28.542391015167105
# evaluation/target_1800_return_std: 1.3708577361211278
# evaluation/target_1800_length_mean: 22.98
# evaluation/target_1800_length_std: 0.7068238818828916
# time/total: 244.7321629524231
# time/evaluation: 124.0813341140747
# training/train_loss_mean: 2.291506372690201
# training/train_loss_std: 0.6547902832800329
# ================================================================================
# Epoch 3
# time/training: 69.07677006721497
# evaluation/target_3600_return_mean: 744.4258188987797
# evaluation/target_3600_return_std: 114.287551691196
# evaluation/target_3600_length_mean: 221.98
# evaluation/target_3600_length_std: 32.31933786450459
# evaluation/target_1800_return_mean: 206.82722734406576
# evaluation/target_1800_return_std: 238.25114455671104
# evaluation/target_1800_length_mean: 80.79
# evaluation/target_1800_length_std: 65.17059075994325
# time/total: 422.652804851532
# time/evaluation: 108.84354782104492
# training/train_loss_mean: 2.27513640999794
# training/train_loss_std: 0.6447395901073526
# ================================================================================
# Epoch 4
# time/training: 57.985804080963135
# evaluation/target_3600_return_mean: 942.2961480781407
# evaluation/target_3600_return_std: 360.73147889491804
# evaluation/target_3600_length_mean: 275.07
# evaluation/target_3600_length_std: 95.46122301751639
# evaluation/target_1800_return_mean: 480.8090580464002
# evaluation/target_1800_return_std: 129.57683981339306
# evaluation/target_1800_length_mean: 166.76
# evaluation/target_1800_length_std: 29.640890674876825
# time/total: 614.2425909042358
# time/evaluation: 133.60363912582397
# training/train_loss_mean: 2.082716642618179
# training/train_loss_std: 0.612974919804861
# ================================================================================
# Epoch 5
# time/training: 55.55122518539429
# evaluation/target_3600_return_mean: 1013.8550598174645
# evaluation/target_3600_return_std: 451.8828444332137
# evaluation/target_3600_length_mean: 292.4
# evaluation/target_3600_length_std: 114.44291153234437
# evaluation/target_1800_return_mean: 803.7052831805825
# evaluation/target_1800_return_std: 185.01976195597067
# evaluation/target_1800_length_mean: 236.95
# evaluation/target_1800_length_std: 39.72238034156563
# time/total: 828.5104629993439
# time/evaluation: 158.7162868976593
# training/train_loss_mean: 1.955393038392067
# training/train_loss_std: 0.6485231176511327
# ================================================================================
# Epoch 6
# time/training: 55.10186290740967
# evaluation/target_3600_return_mean: 1157.811272280925
# evaluation/target_3600_return_std: 663.837726430113
# evaluation/target_3600_length_mean: 334.94
# evaluation/target_3600_length_std: 176.90216618232802
# evaluation/target_1800_return_mean: 922.4898421631319
# evaluation/target_1800_return_std: 98.96091059952242
# evaluation/target_1800_length_mean: 264.55
# evaluation/target_1800_length_std: 24.286776237286002
# time/total: 1063.3083667755127
# time/evaluation: 179.69569993019104
# training/train_loss_mean: 2.1496761411428453
# training/train_loss_std: 0.6518975336018912
# ================================================================================
# Epoch 7
# time/training: 55.30693817138672
# evaluation/target_3600_return_mean: 1422.740828506867
# evaluation/target_3600_return_std: 871.3457424114055
# evaluation/target_3600_length_mean: 417.41
# evaluation/target_3600_length_std: 223.21510231164913
# evaluation/target_1800_return_mean: 1415.0083993794758
# evaluation/target_1800_return_std: 727.4755449377202
# evaluation/target_1800_length_mean: 392.19
# evaluation/target_1800_length_std: 193.66273234672693
# time/total: 1359.870288848877
# time/evaluation: 241.25466203689575
# training/train_loss_mean: 2.0401429426670075
# training/train_loss_std: 0.5744236964301925
# ================================================================================
# Epoch 8
# time/training: 55.13055920600891
# evaluation/target_3600_return_mean: 1100.0506294675513
# evaluation/target_3600_return_std: 563.3954335959965
# evaluation/target_3600_length_mean: 333.29
# evaluation/target_3600_length_std: 136.93343601911113
# evaluation/target_1800_return_mean: 900.0820823957292
# evaluation/target_1800_return_std: 299.7038672834105
# evaluation/target_1800_length_mean: 262.54
# evaluation/target_1800_length_std: 76.63777397602307
# time/total: 1594.2296028137207
# time/evaluation: 179.22842812538147
# training/train_loss_mean: 2.0802834779024124
# training/train_loss_std: 0.6405535008271529
# ================================================================================
# Epoch 9
# time/training: 55.44632697105408
# evaluation/target_3600_return_mean: 670.5201883335533
# evaluation/target_3600_return_std: 71.92964700015187
# evaluation/target_3600_length_mean: 236.84
# evaluation/target_3600_length_std: 21.341377650001885
# evaluation/target_1800_return_mean: 743.7321360251693
# evaluation/target_1800_return_std: 245.25596682272322
# evaluation/target_1800_length_mean: 227.71
# evaluation/target_1800_length_std: 54.22919785503009
# time/total: 1788.7449688911438
# time/evaluation: 139.0687119960785
# training/train_loss_mean: 2.1851275253295896
# training/train_loss_std: 0.6652766620654684
# ================================================================================
# Epoch 10
# time/training: 54.984782218933105
# evaluation/target_3600_return_mean: 721.9018159065502
# evaluation/target_3600_return_std: 48.505913720599914
# evaluation/target_3600_length_mean: 245.15
# evaluation/target_3600_length_std: 13.511014025601483
# evaluation/target_1800_return_mean: 788.502861683659
# evaluation/target_1800_return_std: 404.2211827860573
# evaluation/target_1800_length_mean: 243.41
# evaluation/target_1800_length_std: 103.23043107533746
# time/total: 1991.7703959941864
# time/evaluation: 148.04031896591187
# training/train_loss_mean: 2.163369368314743
# training/train_loss_std: 0.602378497357345

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30, 15))
epochs = 10
Experiment2 = Expt(ax1, ax2, mode='normal', dataset='expert', iterations=100, epochs=epochs, cell_type='RNN')

# %%
Experiment2.experiment()
legend = [f"epoch{math.ceil((num+1)/2)}_{3600 if num%2==0 else 1800}" for num in range(epochs*2)]
ax1.legend(legend, prop={"size":20})
ax2.legend(legend, prop={"size":20})
fig
# Out:
# objc[56373]: Class GLFWApplicationDelegate is implemented in both /Users/karan_bania/.mujoco/mujoco200/bin/libglfw.3.dylib (0x10c5e8778) and /Users/karan_bania/anaconda3/envs/decision-transformer-gym/lib/python3.8/site-packages/glfw/libglfw.3.dylib (0x10d0eb7e8). One of the two will be used. Which one is undefined.
# objc[56373]: Class GLFWWindowDelegate is implemented in both /Users/karan_bania/.mujoco/mujoco200/bin/libglfw.3.dylib (0x10c5e8700) and /Users/karan_bania/anaconda3/envs/decision-transformer-gym/lib/python3.8/site-packages/glfw/libglfw.3.dylib (0x10d0eb810). One of the two will be used. Which one is undefined.
# objc[56373]: Class GLFWContentView is implemented in both /Users/karan_bania/.mujoco/mujoco200/bin/libglfw.3.dylib (0x10c5e87a0) and /Users/karan_bania/anaconda3/envs/decision-transformer-gym/lib/python3.8/site-packages/glfw/libglfw.3.dylib (0x10d0eb860). One of the two will be used. Which one is undefined.
# objc[56373]: Class GLFWWindow is implemented in both /Users/karan_bania/.mujoco/mujoco200/bin/libglfw.3.dylib (0x10c5e8818) and /Users/karan_bania/anaconda3/envs/decision-transformer-gym/lib/python3.8/site-packages/glfw/libglfw.3.dylib (0x10d0eb8d8). One of the two will be used. Which one is undefined.
# ==================================================
# Starting new experiment: expert
# 1027 trajectories, 999494 timesteps found
# Average return: 3511.36, std: 328.59
# Max return: 3759.08, min: 1645.28
# ==================================================
# ================================================================================
# Epoch 1
# time/training: 58.11738395690918
# evaluation/target_3600_return_mean: 418.7243846461759
# evaluation/target_3600_return_std: 8.811335692440256
# evaluation/target_3600_length_mean: 146.78
# evaluation/target_3600_length_std: 2.613732962641746
# evaluation/target_1800_return_mean: 401.81624979807964
# evaluation/target_1800_return_std: 3.445250726059965
# evaluation/target_1800_length_mean: 145.77
# evaluation/target_1800_length_std: 1.4481367338756377
# time/total: 168.4567358493805
# time/evaluation: 110.33933806419373
# training/train_loss_mean: 2.222995935678482
# training/train_loss_std: 0.5637617899560489
# ================================================================================
# Epoch 2
# time/training: 68.22295117378235
# evaluation/target_3600_return_mean: 958.5600610845786
# evaluation/target_3600_return_std: 177.38222447700048
# evaluation/target_3600_length_mean: 283.08
# evaluation/target_3600_length_std: 48.13204338068352
# evaluation/target_1800_return_mean: 1535.2597877152211
# evaluation/target_1800_return_std: 349.20882516301486
# evaluation/target_1800_length_mean: 450.27
# evaluation/target_1800_length_std: 97.19545822722375
# time/total: 513.8267240524292
# time/evaluation: 277.1466329097748
# training/train_loss_mean: 2.150325035452843
# training/train_loss_std: 0.5891866240094245
# ================================================================================
# Epoch 3
# time/training: 67.9586751461029
# evaluation/target_3600_return_mean: 1588.3000182781316
# evaluation/target_3600_return_std: 895.7058184001532
# evaluation/target_3600_length_mean: 459.59
# evaluation/target_3600_length_std: 234.70381739545692
# evaluation/target_1800_return_mean: 1002.3279014192206
# evaluation/target_1800_return_std: 666.2415938383506
# evaluation/target_1800_length_mean: 309.32
# evaluation/target_1800_length_std: 174.56980724054202
# time/total: 880.1322138309479
# time/evaluation: 298.34642601013184
# training/train_loss_mean: 2.166327345371246
# training/train_loss_std: 0.6476910453095291
# ================================================================================
# Epoch 4
# time/training: 75.0035948753357
# evaluation/target_3600_return_mean: 1241.9305237644364
# evaluation/target_3600_return_std: 737.7170603749918
# evaluation/target_3600_length_mean: 364.75
# evaluation/target_3600_length_std: 188.01975295165133
# evaluation/target_1800_return_mean: 604.9996516257315
# evaluation/target_1800_return_std: 351.40577388163774
# evaluation/target_1800_length_mean: 205.26
# evaluation/target_1800_length_std: 92.66537864812295
# time/total: 1162.4538569450378
# time/evaluation: 207.31770277023315
# training/train_loss_mean: 2.174308508038521
# training/train_loss_std: 0.6142785158105109
# ================================================================================
# Epoch 5
# time/training: 66.16936874389648
# evaluation/target_3600_return_mean: 977.1252024451513
# evaluation/target_3600_return_std: 505.8289465081245
# evaluation/target_3600_length_mean: 304.08
# evaluation/target_3600_length_std: 131.0851387457785
# evaluation/target_1800_return_mean: 752.417813884436
# evaluation/target_1800_return_std: 560.099083967243
# evaluation/target_1800_length_mean: 240.43
# evaluation/target_1800_length_std: 142.9543462088509
# time/total: 1431.5742959976196
# time/evaluation: 202.95072197914124
# training/train_loss_mean: 2.1185481929779053
# training/train_loss_std: 0.6161320822355184
# ================================================================================
# Epoch 6
# time/training: 72.38143992424011
# evaluation/target_3600_return_mean: 548.1379279759162
# evaluation/target_3600_return_std: 155.49183134570384
# evaluation/target_3600_length_mean: 192.82
# evaluation/target_3600_length_std: 44.68878606541019
# evaluation/target_1800_return_mean: 655.9887326883995
# evaluation/target_1800_return_std: 270.2111525001444
# evaluation/target_1800_length_mean: 217.56
# evaluation/target_1800_length_std: 71.70834261088454
# time/total: 1663.30632686615
# time/evaluation: 159.35024428367615
# training/train_loss_mean: 2.118790843486786
# training/train_loss_std: 0.5984326280845742
# ================================================================================
# Epoch 7
# time/training: 65.31436800956726
# evaluation/target_3600_return_mean: 987.7918314471681
# evaluation/target_3600_return_std: 441.23197155331434
# evaluation/target_3600_length_mean: 307.06
# evaluation/target_3600_length_std: 111.6125279706539
# evaluation/target_1800_return_mean: 1320.1790685096757
# evaluation/target_1800_return_std: 452.93597919245866
# evaluation/target_1800_length_mean: 377.8
# evaluation/target_1800_length_std: 120.22079686975961
# time/total: 1985.4781959056854
# time/evaluation: 256.8571467399597
# training/train_loss_mean: 2.156321654319763
# training/train_loss_std: 0.5624968292247872
# ================================================================================
# Epoch 8
# time/training: 68.19529700279236
# evaluation/target_3600_return_mean: 504.6545841910196
# evaluation/target_3600_return_std: 278.62069594265904
# evaluation/target_3600_length_mean: 178.9
# evaluation/target_3600_length_std: 72.31424479312496
# evaluation/target_1800_return_mean: 1255.9359240508957
# evaluation/target_1800_return_std: 393.89866940921013
# evaluation/target_1800_length_mean: 365.16
# evaluation/target_1800_length_std: 98.82759938397776
# time/total: 2277.3235969543457
# time/evaluation: 223.64977717399597
# training/train_loss_mean: 2.159317073225975
# training/train_loss_std: 0.6595221439536201
# ================================================================================
# Epoch 9
# time/training: 69.48046112060547
# evaluation/target_3600_return_mean: 654.1719815800985
# evaluation/target_3600_return_std: 432.24260015087583
# evaluation/target_3600_length_mean: 211.75
# evaluation/target_3600_length_std: 107.52872871935202
# evaluation/target_1800_return_mean: 1589.7037084107567
# evaluation/target_1800_return_std: 584.8771114886345
# evaluation/target_1800_length_mean: 448.44
# evaluation/target_1800_length_std: 151.6072768702083
# time/total: 2564.0308740139008
# time/evaluation: 217.22650694847107
# training/train_loss_mean: 2.0885962212085722
# training/train_loss_std: 0.595231688137303
# ================================================================================
# Epoch 10
# time/training: 56.87878608703613
# evaluation/target_3600_return_mean: 1106.267333093872
# evaluation/target_3600_return_std: 694.1978179674833
# evaluation/target_3600_length_mean: 327.88
# evaluation/target_3600_length_std: 174.59417401505698
# evaluation/target_1800_return_mean: 1677.6229062880357
# evaluation/target_1800_return_std: 546.7622174219124
# evaluation/target_1800_length_mean: 467.18
# evaluation/target_1800_length_std: 145.65544136763307
# time/total: 2869.9692981243134
# time/evaluation: 249.0593297481537
# training/train_loss_mean: 2.1503471499681472
# training/train_loss_std: 0.6527396663220195
